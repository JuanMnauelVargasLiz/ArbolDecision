# %% [markdown]
# ## ARBOLES DE DECISION

# %%
### Juan Manuel Vargas Liz

# %%
#Importamos las librerias 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
#Cargamos el dataset y mostramos las 5 primeras filas
data = pd.read_csv("winequality-red.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
data.shape
# Out:
# (1599, 12)

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
plt.hist(data.quality)
# Out:
# (array([ 10.,   0.,  53.,   0., 681.,   0., 638.,   0., 199.,  18.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.scatterplot(x = "free sulfur dioxide", y = "total sulfur dioxide", hue = "quality", data = data)
# Out:
# <Axes: xlabel='free sulfur dioxide', ylabel='total sulfur dioxide'>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar']])
plt.xticks(rotation=45)
plt.title('Boxplot de Sepal y Petal')
plt.ylabel('Valores')
plt.show()

# %%
predictors_col = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar']
target_col = ['quality']

# %%
predictors = data[predictors_col]
target = data[target_col]

# %%
predictors
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar
# 0               7.4             0.700         0.00             1.9
# 1               7.8             0.880         0.00             2.6
# 2               7.8             0.760         0.04             2.3
# 3              11.2             0.280         0.56             1.9
# 4               7.4             0.700         0.00             1.9
# ...             ...               ...          ...             ...
# 1594            6.2             0.600         0.08             2.0
# 1595            5.9             0.550         0.10             2.2
# 1596            6.3             0.510         0.13             2.3
# 1597            5.9             0.645         0.12             2.0
# 1598            6.0             0.310         0.47             3.6
#
# [1599 rows x 4 columns]

# %%
target
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...       ...
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#
# [1599 rows x 1 columns]

# %%
corr = predictors.corr()
corr
# Out:
#                   fixed acidity  volatile acidity  citric acid  residual sugar
# fixed acidity          1.000000         -0.256131     0.671703        0.114777
# volatile acidity      -0.256131          1.000000    -0.552496        0.001918
# citric acid            0.671703         -0.552496     1.000000        0.143577
# residual sugar         0.114777          0.001918     0.143577        1.000000

# %%
sns.heatmap(corr)
plt.title('Matriz de Correlación')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.2, random_state=13)

# %%
tree = DecisionTreeClassifier()

# %%
arbol = tree.fit(X_train, y_train)

# %%
plot_tree(arbol)
# Out:
# [Text(0.5036130662209942, 0.9833333333333333, 'x[1] <= 0.548\ngini = 0.646\nsamples = 1279\nvalue = [9.0, 45.0, 535.0, 514.0, 164.0, 12.0]'),
#  Text(0.1885447101541328, 0.95, 'x[1] <= 0.317\ngini = 0.649\nsamples = 699\nvalue = [1, 14, 210, 331, 133, 10]'),
#  Text(0.3460788881875635, 0.9666666666666666, 'True  '),
#  Text(0.03753810975609756, 0.9166666666666666, 'x[3] <= 1.65\ngini = 0.597\nsamples = 145\nvalue = [0, 1, 15, 73, 54, 2]'),
#  Text(0.005420054200542005, 0.8833333333333333, 'x[2] <= 0.23\ngini = 0.34\nsamples = 20\nvalue = [0, 0, 2, 16, 2, 0]'),
#  Text(0.0027100271002710027, 0.85, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.008130081300813009, 0.85, 'x[3] <= 1.55\ngini = 0.277\nsamples = 19\nvalue = [0, 0, 2, 16, 1, 0]'),
#  Text(0.005420054200542005, 0.8166666666666667, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.01084010840108401, 0.8166666666666667, 'x[2] <= 0.38\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 2, 6, 1, 0]'),
#  Text(0.008130081300813009, 0.7833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.013550135501355014, 0.7833333333333333, 'x[0] <= 7.45\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 2, 6, 0, 0]'),
#  Text(0.01084010840108401, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.016260162601626018, 0.75, 'x[2] <= 0.495\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 6, 0, 0]'),
#  Text(0.013550135501355014, 0.7166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.018970189701897018, 0.7166666666666667, 'x[1] <= 0.295\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.016260162601626018, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.02168021680216802, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.06965616531165311, 0.8833333333333333, 'x[0] <= 7.8\ngini = 0.608\nsamples = 125\nvalue = [0, 1, 13, 57, 52, 2]'),
#  Text(0.04098915989159892, 0.85, 'x[2] <= 0.36\ngini = 0.395\nsamples = 20\nvalue = [0, 0, 1, 15, 4, 0]'),
#  Text(0.03827913279132791, 0.8166666666666667, 'x[1] <= 0.265\ngini = 0.58\nsamples = 10\nvalue = [0, 0, 1, 5, 4, 0]'),
#  Text(0.032859078590785906, 0.7833333333333333, 'x[0] <= 6.45\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.030149051490514906, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.03556910569105691, 0.75, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.04369918699186992, 0.7833333333333333, 'x[3] <= 1.85\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 1, 4, 0]'),
#  Text(0.04098915989159892, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.046409214092140924, 0.75, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.04369918699186992, 0.8166666666666667, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.09832317073170732, 0.85, 'x[2] <= 0.325\ngini = 0.618\nsamples = 105\nvalue = [0, 1, 12, 42, 48, 2]'),
#  Text(0.09561314363143632, 0.8166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.10103319783197832, 0.8166666666666667, 'x[0] <= 11.15\ngini = 0.618\nsamples = 100\nvalue = [0, 1, 12, 37, 48, 2]'),
#  Text(0.07740514905149051, 0.7833333333333333, 'x[3] <= 2.525\ngini = 0.63\nsamples = 81\nvalue = [0, 1, 12, 26, 40, 2]'),
#  Text(0.051829268292682924, 0.75, 'x[2] <= 0.365\ngini = 0.59\nsamples = 64\nvalue = [0, 1, 6, 22, 34, 1]'),
#  Text(0.02981029810298103, 0.7166666666666667, 'x[0] <= 9.3\ngini = 0.278\nsamples = 12\nvalue = [0, 0, 0, 2, 10, 0]'),
#  Text(0.02710027100271003, 0.6833333333333333, 'x[3] <= 1.95\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 1, 10, 0]'),
#  Text(0.024390243902439025, 0.65, 'x[1] <= 0.285\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]'),
#  Text(0.02168021680216802, 0.6166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.02710027100271003, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.02981029810298103, 0.65, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.032520325203252036, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.07384823848238482, 0.7166666666666667, 'x[0] <= 10.45\ngini = 0.625\nsamples = 52\nvalue = [0, 1, 6, 20, 24, 1]'),
#  Text(0.058265582655826556, 0.6833333333333333, 'x[0] <= 9.85\ngini = 0.648\nsamples = 43\nvalue = [0, 1, 6, 18, 17, 1]'),
#  Text(0.04200542005420054, 0.65, 'x[2] <= 0.445\ngini = 0.607\nsamples = 32\nvalue = [0, 0, 5, 11, 16, 0]'),
#  Text(0.032520325203252036, 0.6166666666666667, 'x[3] <= 1.85\ngini = 0.635\nsamples = 20\nvalue = [0, 0, 4, 9, 7, 0]'),
#  Text(0.02710027100271003, 0.5833333333333334, 'x[1] <= 0.295\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 0, 1, 0]'),
#  Text(0.024390243902439025, 0.55, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.02981029810298103, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.037940379403794036, 0.5833333333333334, 'x[2] <= 0.415\ngini = 0.539\nsamples = 16\nvalue = [0, 0, 1, 9, 6, 0]'),
#  Text(0.03523035230352303, 0.55, 'x[0] <= 8.5\ngini = 0.562\nsamples = 11\nvalue = [0, 0, 1, 4, 6, 0]'),
#  Text(0.032520325203252036, 0.5166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.037940379403794036, 0.5166666666666667, 'x[0] <= 8.95\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 1, 4, 1, 0]'),
#  Text(0.03523035230352303, 0.48333333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.04065040650406504, 0.48333333333333334, 'x[1] <= 0.285\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.037940379403794036, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.04336043360433604, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.04065040650406504, 0.55, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.051490514905149054, 0.6166666666666667, 'x[2] <= 0.565\ngini = 0.403\nsamples = 12\nvalue = [0, 0, 1, 2, 9, 0]'),
#  Text(0.04878048780487805, 0.5833333333333334, 'x[0] <= 7.95\ngini = 0.298\nsamples = 11\nvalue = [0, 0, 0, 2, 9, 0]'),
#  Text(0.04607046070460705, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.051490514905149054, 0.55, 'x[1] <= 0.245\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 0, 1, 9, 0]'),
#  Text(0.04878048780487805, 0.5166666666666667, 'x[1] <= 0.2\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]'),
#  Text(0.04607046070460705, 0.48333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.051490514905149054, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.05420054200542006, 0.5166666666666667, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.05420054200542006, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.07452574525745258, 0.65, 'x[1] <= 0.245\ngini = 0.562\nsamples = 11\nvalue = [0, 1, 1, 7, 1, 1]'),
#  Text(0.06504065040650407, 0.6166666666666667, 'x[0] <= 10.3\ngini = 0.75\nsamples = 4\nvalue = [0, 1, 1, 1, 1, 0]'),
#  Text(0.05962059620596206, 0.5833333333333334, 'x[1] <= 0.235\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.056910569105691054, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.06233062330623306, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.07046070460704607, 0.5833333333333334, 'x[2] <= 0.475\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.06775067750677506, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.07317073170731707, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.08401084010840108, 0.6166666666666667, 'x[0] <= 10.05\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 0, 1]'),
#  Text(0.08130081300813008, 0.5833333333333334, 'x[0] <= 9.95\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.07859078590785908, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.08401084010840108, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.08672086720867209, 0.5833333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.08943089430894309, 0.6833333333333333, 'x[3] <= 1.75\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 0, 2, 7, 0]'),
#  Text(0.08672086720867209, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.0921409214092141, 0.65, 'x[1] <= 0.305\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 1, 7, 0]'),
#  Text(0.08943089430894309, 0.6166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.0948509485094851, 0.6166666666666667, 'x[2] <= 0.51\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.0921409214092141, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.0975609756097561, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.10298102981029811, 0.75, 'x[1] <= 0.255\ngini = 0.692\nsamples = 17\nvalue = [0, 0, 6, 4, 6, 1]'),
#  Text(0.1002710027100271, 0.7166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.10569105691056911, 0.7166666666666667, 'x[3] <= 3.55\ngini = 0.622\nsamples = 14\nvalue = [0, 0, 6, 1, 6, 1]'),
#  Text(0.1002710027100271, 0.6833333333333333, 'x[1] <= 0.295\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 6, 0, 2, 1]'),
#  Text(0.0975609756097561, 0.65, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.10298102981029811, 0.65, 'x[1] <= 0.305\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 0, 2, 1]'),
#  Text(0.1002710027100271, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.10569105691056911, 0.6166666666666667, 'x[2] <= 0.38\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.10298102981029811, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.10840108401084012, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.1111111111111111, 0.6833333333333333, 'x[2] <= 0.475\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 1, 4, 0]'),
#  Text(0.10840108401084012, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.11382113821138211, 0.65, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.12466124661246612, 0.7833333333333333, 'x[0] <= 11.65\ngini = 0.488\nsamples = 19\nvalue = [0, 0, 0, 11, 8, 0]'),
#  Text(0.12195121951219512, 0.75, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.12737127371273713, 0.75, 'x[1] <= 0.305\ngini = 0.397\nsamples = 11\nvalue = [0, 0, 0, 3, 8, 0]'),
#  Text(0.12466124661246612, 0.7166666666666667, 'x[3] <= 2.95\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 0, 2, 8, 0]'),
#  Text(0.12195121951219512, 0.6833333333333333, 'x[0] <= 13.35\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 1, 8, 0]'),
#  Text(0.11924119241192412, 0.65, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.12466124661246612, 0.65, 'x[0] <= 14.2\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.12195121951219512, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.12737127371273713, 0.6166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.12737127371273713, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.13008130081300814, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.33955131055216803, 0.9166666666666666, 'x[3] <= 3.35\ngini = 0.638\nsamples = 554\nvalue = [1, 13, 195, 258, 79, 8]'),
#  Text(0.1960402904810298, 0.8833333333333333, 'x[3] <= 3.15\ngini = 0.617\nsamples = 483\nvalue = [1, 8, 173, 237, 57, 7]'),
#  Text(0.19333026338075882, 0.85, 'x[0] <= 5.55\ngini = 0.621\nsamples = 473\nvalue = [1, 8, 173, 227, 57, 7]'),
#  Text(0.14092140921409213, 0.8166666666666667, 'x[1] <= 0.38\ngini = 0.698\nsamples = 13\nvalue = [0, 1, 1, 3, 6, 2]'),
#  Text(0.13550135501355012, 0.7833333333333333, 'x[1] <= 0.33\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.13279132791327913, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.13821138211382114, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.14634146341463414, 0.7833333333333333, 'x[3] <= 2.25\ngini = 0.58\nsamples = 10\nvalue = [0, 1, 0, 1, 6, 2]'),
#  Text(0.14363143631436315, 0.75, 'x[0] <= 4.75\ngini = 0.494\nsamples = 9\nvalue = [0, 1, 0, 0, 6, 2]'),
#  Text(0.14092140921409213, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.14634146341463414, 0.7166666666666667, 'x[0] <= 5.45\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 0, 0, 6, 2]'),
#  Text(0.14363143631436315, 0.6833333333333333, 'x[0] <= 5.05\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 0, 6, 1]'),
#  Text(0.14092140921409213, 0.65, 'x[0] <= 4.95\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.13821138211382114, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.14363143631436315, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.14634146341463414, 0.65, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.14905149051490515, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.14905149051490515, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.24573911754742547, 0.8166666666666667, 'x[2] <= 0.315\ngini = 0.61\nsamples = 460\nvalue = [1, 7, 172, 224, 51, 5]'),
#  Text(0.17567538956639567, 0.7833333333333333, 'x[3] <= 1.65\ngini = 0.551\nsamples = 213\nvalue = [0, 5, 84, 115, 8, 1]'),
#  Text(0.16260162601626016, 0.75, 'x[3] <= 1.45\ngini = 0.401\nsamples = 18\nvalue = [0, 0, 13, 5, 0, 0]'),
#  Text(0.15718157181571815, 0.7166666666666667, 'x[0] <= 6.15\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 2, 4, 0, 0]'),
#  Text(0.15447154471544716, 0.6833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.15989159891598917, 0.6833333333333333, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.16802168021680217, 0.7166666666666667, 'x[1] <= 0.445\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 11, 1, 0, 0]'),
#  Text(0.16531165311653118, 0.6833333333333333, 'x[1] <= 0.435\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.16260162601626016, 0.65, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.16802168021680217, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.17073170731707318, 0.6833333333333333, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.18874915311653118, 0.75, 'x[2] <= 0.025\ngini = 0.547\nsamples = 195\nvalue = [0, 5, 71, 110, 8, 1]'),
#  Text(0.17886178861788618, 0.7166666666666667, 'x[3] <= 2.15\ngini = 0.153\nsamples = 12\nvalue = [0, 1, 0, 11, 0, 0]'),
#  Text(0.17615176151761516, 0.6833333333333333, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.18157181571815717, 0.6833333333333333, 'x[3] <= 2.25\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.17886178861788618, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.1842818428184282, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.19863651761517614, 0.7166666666666667, 'x[0] <= 5.8\ngini = 0.554\nsamples = 183\nvalue = [0.0, 4.0, 71.0, 99.0, 8.0, 1.0]'),
#  Text(0.19592649051490515, 0.6833333333333333, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.20134654471544716, 0.6833333333333333, 'x[1] <= 0.345\ngini = 0.551\nsamples = 179\nvalue = [0, 4, 67, 99, 8, 1]'),
#  Text(0.1897018970189702, 0.65, 'x[3] <= 2.4\ngini = 0.42\nsamples = 10\nvalue = [0, 0, 7, 3, 0, 0]'),
#  Text(0.18699186991869918, 0.6166666666666667, 'x[2] <= 0.295\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 7, 1, 0, 0]'),
#  Text(0.1842818428184282, 0.5833333333333334, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.1897018970189702, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.19241192411924118, 0.6166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.21299119241192413, 0.65, 'x[0] <= 6.65\ngini = 0.548\nsamples = 169\nvalue = [0, 4, 60, 96, 8, 1]'),
#  Text(0.1978319783197832, 0.6166666666666667, 'x[2] <= 0.27\ngini = 0.355\nsamples = 23\nvalue = [0, 0, 4, 18, 1, 0]'),
#  Text(0.1951219512195122, 0.5833333333333334, 'x[3] <= 1.85\ngini = 0.31\nsamples = 22\nvalue = [0, 0, 3, 18, 1, 0]'),
#  Text(0.1897018970189702, 0.55, 'x[1] <= 0.415\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 2, 3, 1, 0]'),
#  Text(0.18699186991869918, 0.5166666666666667, 'x[2] <= 0.155\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 1, 0]'),
#  Text(0.1842818428184282, 0.48333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.1897018970189702, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.19241192411924118, 0.5166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.2005420054200542, 0.55, 'x[3] <= 2.35\ngini = 0.117\nsamples = 16\nvalue = [0, 0, 1, 15, 0, 0]'),
#  Text(0.1978319783197832, 0.5166666666666667, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.2032520325203252, 0.5166666666666667, 'x[1] <= 0.485\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.2005420054200542, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.20596205962059622, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2005420054200542, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.22815040650406504, 0.6166666666666667, 'x[2] <= 0.035\ngini = 0.564\nsamples = 146\nvalue = [0, 4, 56, 78, 7, 1]'),
#  Text(0.22544037940379405, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.23086043360433606, 0.5833333333333334, 'x[2] <= 0.075\ngini = 0.563\nsamples = 144\nvalue = [0, 4, 54, 78, 7, 1]'),
#  Text(0.22815040650406504, 0.55, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.23357046070460705, 0.55, 'x[2] <= 0.095\ngini = 0.568\nsamples = 140\nvalue = [0, 4, 54, 74, 7, 1]'),
#  Text(0.2140921409214092, 0.5166666666666667, 'x[1] <= 0.515\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 3, 1, 2, 0]'),
#  Text(0.21138211382113822, 0.48333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.21680216802168023, 0.48333333333333334, 'x[3] <= 2.25\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.2140921409214092, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.21951219512195122, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.2530487804878049, 0.5166666666666667, 'x[1] <= 0.543\ngini = 0.556\nsamples = 134\nvalue = [0, 4, 51, 73, 5, 1]'),
#  Text(0.25033875338753386, 0.48333333333333334, 'x[2] <= 0.295\ngini = 0.56\nsamples = 131\nvalue = [0, 4, 51, 70, 5, 1]'),
#  Text(0.22493224932249323, 0.45, 'x[0] <= 9.95\ngini = 0.552\nsamples = 101\nvalue = [0, 4, 43, 52, 2, 0]'),
#  Text(0.2222222222222222, 0.4166666666666667, 'x[0] <= 8.75\ngini = 0.554\nsamples = 99\nvalue = [0, 4, 43, 50, 2, 0]'),
#  Text(0.2005420054200542, 0.38333333333333336, 'x[0] <= 7.75\ngini = 0.544\nsamples = 89\nvalue = [0, 3, 36, 48, 2, 0]'),
#  Text(0.1856368563685637, 0.35, 'x[1] <= 0.535\ngini = 0.56\nsamples = 62\nvalue = [0, 3, 29, 29, 1, 0]'),
#  Text(0.18292682926829268, 0.31666666666666665, 'x[3] <= 2.25\ngini = 0.561\nsamples = 58\nvalue = [0, 3, 25, 29, 1, 0]'),
#  Text(0.16802168021680217, 0.2833333333333333, 'x[0] <= 7.25\ngini = 0.589\nsamples = 35\nvalue = [0, 3, 18, 13, 1, 0]'),
#  Text(0.15718157181571815, 0.25, 'x[3] <= 1.75\ngini = 0.568\nsamples = 18\nvalue = [0, 2, 6, 10, 0, 0]'),
#  Text(0.15447154471544716, 0.21666666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.15989159891598917, 0.21666666666666667, 'x[0] <= 7.15\ngini = 0.604\nsamples = 15\nvalue = [0, 2, 6, 7, 0, 0]'),
#  Text(0.15447154471544716, 0.18333333333333332, 'x[3] <= 1.85\ngini = 0.593\nsamples = 9\nvalue = [0, 2, 5, 2, 0, 0]'),
#  Text(0.15176151761517614, 0.15, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.15718157181571815, 0.15, 'x[2] <= 0.245\ngini = 0.667\nsamples = 6\nvalue = [0, 2, 2, 2, 0, 0]'),
#  Text(0.15447154471544716, 0.11666666666666667, 'x[3] <= 2.05\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 0, 2, 0, 0]'),
#  Text(0.15176151761517614, 0.08333333333333333, 'x[2] <= 0.215\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]'),
#  Text(0.14905149051490515, 0.05, 'x[0] <= 7.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.14634146341463414, 0.016666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.15176151761517614, 0.016666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.15447154471544716, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.15718157181571815, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.15989159891598917, 0.11666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.16531165311653118, 0.18333333333333332, 'x[3] <= 2.15\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(0.16260162601626016, 0.15, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.16802168021680217, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.17886178861788618, 0.25, 'x[1] <= 0.365\ngini = 0.464\nsamples = 17\nvalue = [0, 1, 12, 3, 1, 0]'),
#  Text(0.17615176151761516, 0.21666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.18157181571815717, 0.21666666666666667, 'x[0] <= 7.65\ngini = 0.398\nsamples = 16\nvalue = [0, 0, 12, 3, 1, 0]'),
#  Text(0.17886178861788618, 0.18333333333333332, 'x[2] <= 0.17\ngini = 0.512\nsamples = 11\nvalue = [0, 0, 7, 3, 1, 0]'),
#  Text(0.17344173441734417, 0.15, 'x[1] <= 0.525\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.17073170731707318, 0.11666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.17615176151761516, 0.11666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.1842818428184282, 0.15, 'x[2] <= 0.185\ngini = 0.444\nsamples = 9\nvalue = [0, 0, 6, 3, 0, 0]'),
#  Text(0.18157181571815717, 0.11666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.18699186991869918, 0.11666666666666667, 'x[2] <= 0.265\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 6, 2, 0, 0]'),
#  Text(0.1842818428184282, 0.08333333333333333, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.1897018970189702, 0.08333333333333333, 'x[2] <= 0.28\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.18699186991869918, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.19241192411924118, 0.05, 'x[1] <= 0.415\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.1897018970189702, 0.016666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1951219512195122, 0.016666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.1842818428184282, 0.18333333333333332, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.1978319783197832, 0.2833333333333333, 'x[3] <= 2.55\ngini = 0.423\nsamples = 23\nvalue = [0, 0, 7, 16, 0, 0]'),
#  Text(0.1951219512195122, 0.25, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.2005420054200542, 0.25, 'x[0] <= 7.45\ngini = 0.497\nsamples = 13\nvalue = [0, 0, 7, 6, 0, 0]'),
#  Text(0.1951219512195122, 0.21666666666666667, 'x[2] <= 0.215\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.19241192411924118, 0.18333333333333332, 'x[3] <= 2.65\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.1897018970189702, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.1951219512195122, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1978319783197832, 0.18333333333333332, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.20596205962059622, 0.21666666666666667, 'x[2] <= 0.13\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 2, 5, 0, 0]'),
#  Text(0.2032520325203252, 0.18333333333333332, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2086720867208672, 0.18333333333333332, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.18834688346883469, 0.31666666666666665, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.21544715447154472, 0.35, 'x[1] <= 0.385\ngini = 0.436\nsamples = 27\nvalue = [0, 0, 7, 19, 1, 0]'),
#  Text(0.20596205962059622, 0.31666666666666665, 'x[0] <= 8.0\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 1, 0]'),
#  Text(0.2032520325203252, 0.2833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2086720867208672, 0.2833333333333333, 'x[2] <= 0.24\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.20596205962059622, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.21138211382113822, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.22493224932249323, 0.31666666666666665, 'x[2] <= 0.245\ngini = 0.34\nsamples = 23\nvalue = [0, 0, 5, 18, 0, 0]'),
#  Text(0.2222222222222222, 0.2833333333333333, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.22764227642276422, 0.2833333333333333, 'x[3] <= 1.95\ngini = 0.43\nsamples = 16\nvalue = [0, 0, 5, 11, 0, 0]'),
#  Text(0.21680216802168023, 0.25, 'x[1] <= 0.505\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]'),
#  Text(0.2140921409214092, 0.21666666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.21951219512195122, 0.21666666666666667, 'x[2] <= 0.255\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.21680216802168023, 0.18333333333333332, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2222222222222222, 0.18333333333333332, 'x[0] <= 8.1\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.21951219512195122, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.22493224932249323, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.23848238482384823, 0.25, 'x[2] <= 0.265\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 4, 4, 0, 0]'),
#  Text(0.23577235772357724, 0.21666666666666667, 'x[3] <= 2.25\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.23306233062330622, 0.18333333333333332, 'x[2] <= 0.255\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.23035230352303523, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.23577235772357724, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.23848238482384823, 0.18333333333333332, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.24119241192411925, 0.21666666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.24390243902439024, 0.38333333333333336, 'x[0] <= 9.4\ngini = 0.46\nsamples = 10\nvalue = [0, 1, 7, 2, 0, 0]'),
#  Text(0.23848238482384823, 0.35, 'x[3] <= 2.35\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.23577235772357724, 0.31666666666666665, 'x[2] <= 0.25\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.23306233062330622, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.23848238482384823, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.24119241192411925, 0.31666666666666665, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.24932249322493225, 0.35, 'x[2] <= 0.25\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 1, 0, 0]'),
#  Text(0.24661246612466126, 0.31666666666666665, 'x[3] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.24390243902439024, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.24932249322493225, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.25203252032520324, 0.31666666666666665, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.22764227642276422, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2757452574525745, 0.45, 'x[3] <= 2.225\ngini = 0.558\nsamples = 30\nvalue = [0, 0, 8, 18, 3, 1]'),
#  Text(0.26422764227642276, 0.4166666666666667, 'x[1] <= 0.37\ngini = 0.377\nsamples = 18\nvalue = [0, 0, 2, 14, 1, 1]'),
#  Text(0.25745257452574527, 0.38333333333333336, 'x[2] <= 0.305\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.25474254742547425, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.2601626016260163, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.27100271002710025, 0.38333333333333336, 'x[3] <= 2.05\ngini = 0.32\nsamples = 16\nvalue = [0, 0, 2, 13, 1, 0]'),
#  Text(0.26558265582655827, 0.35, 'x[1] <= 0.395\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10, 0, 0]'),
#  Text(0.26287262872628725, 0.31666666666666665, 'x[1] <= 0.385\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.2601626016260163, 0.2833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.26558265582655827, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2682926829268293, 0.31666666666666665, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.2764227642276423, 0.35, 'x[2] <= 0.305\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 1, 3, 1, 0]'),
#  Text(0.27371273712737126, 0.31666666666666665, 'x[0] <= 7.05\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 1, 0]'),
#  Text(0.27100271002710025, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2764227642276423, 0.2833333333333333, 'x[3] <= 2.15\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.27371273712737126, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2791327913279133, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2791327913279133, 0.31666666666666665, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2872628726287263, 0.4166666666666667, 'x[3] <= 2.35\ngini = 0.611\nsamples = 12\nvalue = [0, 0, 6, 4, 2, 0]'),
#  Text(0.2845528455284553, 0.38333333333333336, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.2899728997289973, 0.38333333333333336, 'x[0] <= 8.1\ngini = 0.642\nsamples = 9\nvalue = [0, 0, 3, 4, 2, 0]'),
#  Text(0.2872628726287263, 0.35, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2926829268292683, 0.35, 'x[0] <= 9.3\ngini = 0.653\nsamples = 7\nvalue = [0, 0, 3, 2, 2, 0]'),
#  Text(0.2899728997289973, 0.31666666666666665, 'x[1] <= 0.475\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 3, 2, 1, 0]'),
#  Text(0.2872628726287263, 0.2833333333333333, 'x[1] <= 0.465\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.2845528455284553, 0.25, 'x[3] <= 2.55\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.28184281842818426, 0.21666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2872628726287263, 0.21666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2899728997289973, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2926829268292683, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2953929539295393, 0.31666666666666665, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2557588075880759, 0.48333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.3158028455284553, 0.7833333333333333, 'x[0] <= 7.35\ngini = 0.648\nsamples = 247\nvalue = [1, 2, 88, 109, 43, 4]'),
#  Text(0.26355013550135503, 0.75, 'x[1] <= 0.375\ngini = 0.635\nsamples = 21\nvalue = [0, 0, 5, 6, 10, 0]'),
#  Text(0.252710027100271, 0.7166666666666667, 'x[2] <= 0.465\ngini = 0.43\nsamples = 11\nvalue = [0, 0, 2, 1, 8, 0]'),
#  Text(0.247289972899729, 0.6833333333333333, 'x[3] <= 2.45\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 0, 8, 0]'),
#  Text(0.244579945799458, 0.65, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.25, 0.65, 'x[0] <= 7.25\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.247289972899729, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.252710027100271, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.258130081300813, 0.6833333333333333, 'x[3] <= 2.3\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.255420054200542, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.260840108401084, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.27439024390243905, 0.7166666666666667, 'x[2] <= 0.38\ngini = 0.62\nsamples = 10\nvalue = [0, 0, 3, 5, 2, 0]'),
#  Text(0.268970189701897, 0.6833333333333333, 'x[1] <= 0.425\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 3, 1, 1, 0]'),
#  Text(0.266260162601626, 0.65, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.27168021680216803, 0.65, 'x[2] <= 0.34\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.268970189701897, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.27439024390243905, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.279810298102981, 0.6833333333333333, 'x[0] <= 6.3\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1, 0]'),
#  Text(0.27710027100271, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.28252032520325204, 0.65, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.3680555555555556, 0.75, 'x[1] <= 0.375\ngini = 0.636\nsamples = 226\nvalue = [1, 2, 83, 103, 33, 4]'),
#  Text(0.31639566395663954, 0.7166666666666667, 'x[0] <= 8.45\ngini = 0.611\nsamples = 72\nvalue = [0, 0, 18, 39, 13, 2]'),
#  Text(0.29065040650406504, 0.6833333333333333, 'x[3] <= 2.65\ngini = 0.459\nsamples = 22\nvalue = [0.0, 0.0, 1.0, 15.0, 6.0, 0.0]'),
#  Text(0.287940379403794, 0.65, 'x[3] <= 2.35\ngini = 0.395\nsamples = 20\nvalue = [0, 0, 1, 15, 4, 0]'),
#  Text(0.28523035230352306, 0.6166666666666667, 'x[0] <= 7.6\ngini = 0.5\nsamples = 14\nvalue = [0, 0, 1, 9, 4, 0]'),
#  Text(0.28252032520325204, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.287940379403794, 0.5833333333333334, 'x[3] <= 2.25\ngini = 0.462\nsamples = 13\nvalue = [0, 0, 1, 9, 3, 0]'),
#  Text(0.28116531165311653, 0.55, 'x[3] <= 1.65\ngini = 0.34\nsamples = 10\nvalue = [0, 0, 1, 8, 1, 0]'),
#  Text(0.2757452574525745, 0.5166666666666667, 'x[2] <= 0.425\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.27303523035230354, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2784552845528455, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2865853658536585, 0.5166666666666667, 'x[3] <= 1.95\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 7, 1, 0]'),
#  Text(0.28387533875338755, 0.48333333333333334, 'x[0] <= 8.05\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.28116531165311653, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2865853658536585, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.28929539295392953, 0.48333333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.29471544715447157, 0.55, 'x[0] <= 8.25\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.29200542005420055, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.29742547425474253, 0.5166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.29065040650406504, 0.6166666666666667, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.29336043360433606, 0.65, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.3421409214092141, 0.6833333333333333, 'x[2] <= 0.635\ngini = 0.633\nsamples = 50\nvalue = [0.0, 0.0, 17.0, 24.0, 7.0, 2.0]'),
#  Text(0.3394308943089431, 0.65, 'x[3] <= 2.15\ngini = 0.656\nsamples = 44\nvalue = [0, 0, 17, 18, 7, 2]'),
#  Text(0.31775067750677505, 0.6166666666666667, 'x[2] <= 0.475\ngini = 0.505\nsamples = 20\nvalue = [0, 0, 5, 13, 2, 0]'),
#  Text(0.31097560975609756, 0.5833333333333334, 'x[0] <= 8.8\ngini = 0.314\nsamples = 11\nvalue = [0, 0, 1, 9, 1, 0]'),
#  Text(0.3055555555555556, 0.55, 'x[1] <= 0.355\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.30284552845528456, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.30826558265582654, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.31639566395663954, 0.55, 'x[2] <= 0.385\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 8, 1, 0]'),
#  Text(0.3136856368563686, 0.5166666666666667, 'x[1] <= 0.355\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.31097560975609756, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.31639566395663954, 0.48333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.31910569105691056, 0.5166666666666667, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.3245257452574526, 0.5833333333333334, 'x[2] <= 0.49\ngini = 0.593\nsamples = 9\nvalue = [0, 0, 4, 4, 1, 0]'),
#  Text(0.3218157181571816, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.32723577235772355, 0.55, 'x[0] <= 9.15\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 4, 4, 0, 0]'),
#  Text(0.3245257452574526, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.32994579945799457, 0.5166666666666667, 'x[1] <= 0.335\ngini = 0.49\nsamples = 7\nvalue = [0, 0, 4, 3, 0, 0]'),
#  Text(0.3245257452574526, 0.48333333333333334, 'x[0] <= 9.6\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.3218157181571816, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.32723577235772355, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3353658536585366, 0.48333333333333334, 'x[0] <= 9.7\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.3326558265582656, 0.45, 'gini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.33807588075880757, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3611111111111111, 0.6166666666666667, 'x[0] <= 11.9\ngini = 0.656\nsamples = 24\nvalue = [0, 0, 12, 5, 5, 2]'),
#  Text(0.3584010840108401, 0.5833333333333334, 'x[1] <= 0.335\ngini = 0.599\nsamples = 21\nvalue = [0, 0, 12, 2, 5, 2]'),
#  Text(0.3516260162601626, 0.55, 'x[0] <= 10.2\ngini = 0.594\nsamples = 8\nvalue = [0, 0, 3, 1, 4, 0]'),
#  Text(0.3489159891598916, 0.5166666666666667, 'x[3] <= 2.7\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 3, 1, 2, 0]'),
#  Text(0.3462059620596206, 0.48333333333333334, 'x[0] <= 9.65\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 0, 2, 0]'),
#  Text(0.3434959349593496, 0.45, 'x[2] <= 0.41\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.3407859078590786, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3462059620596206, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.3489159891598916, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3516260162601626, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3543360433604336, 0.5166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.36517615176151763, 0.55, 'x[0] <= 10.65\ngini = 0.485\nsamples = 13\nvalue = [0, 0, 9, 1, 1, 2]'),
#  Text(0.3597560975609756, 0.5166666666666667, 'x[2] <= 0.355\ngini = 0.34\nsamples = 10\nvalue = [0, 0, 8, 1, 1, 0]'),
#  Text(0.35704607046070463, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3624661246612466, 0.48333333333333334, 'x[0] <= 10.4\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 8, 1, 0, 0]'),
#  Text(0.3597560975609756, 0.45, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.36517615176151763, 0.45, 'x[2] <= 0.53\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.3624661246612466, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3678861788617886, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3705962059620596, 0.5166666666666667, 'x[2] <= 0.505\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 0, 2]'),
#  Text(0.3678861788617886, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.37330623306233063, 0.48333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.3638211382113821, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.3448509485094851, 0.65, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.41971544715447157, 0.7166666666666667, 'x[2] <= 0.335\ngini = 0.632\nsamples = 154\nvalue = [1.0, 2.0, 65.0, 64.0, 20.0, 2.0]'),
#  Text(0.41700542005420055, 0.6833333333333333, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.42242547425474253, 0.6833333333333333, 'x[0] <= 10.05\ngini = 0.637\nsamples = 144\nvalue = [1, 2, 55, 64, 20, 2]'),
#  Text(0.404810298102981, 0.65, 'x[2] <= 0.62\ngini = 0.604\nsamples = 74\nvalue = [0, 1, 35, 30, 6, 2]'),
#  Text(0.40210027100271, 0.6166666666666667, 'x[2] <= 0.515\ngini = 0.613\nsamples = 69\nvalue = [0, 1, 30, 30, 6, 2]'),
#  Text(0.3953252032520325, 0.5833333333333334, 'x[2] <= 0.495\ngini = 0.608\nsamples = 64\nvalue = [0, 1, 30, 26, 5, 2]'),
#  Text(0.38990514905149054, 0.55, 'x[0] <= 7.45\ngini = 0.591\nsamples = 60\nvalue = [0, 1, 28, 26, 3, 2]'),
#  Text(0.3871951219512195, 0.5166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.3926151761517615, 0.5166666666666667, 'x[0] <= 8.45\ngini = 0.595\nsamples = 57\nvalue = [0, 1, 25, 26, 3, 2]'),
#  Text(0.3787262872628726, 0.48333333333333334, 'x[1] <= 0.53\ngini = 0.531\nsamples = 14\nvalue = [0, 1, 3, 9, 0, 1]'),
#  Text(0.37601626016260165, 0.45, 'x[3] <= 2.85\ngini = 0.462\nsamples = 13\nvalue = [0, 1, 3, 9, 0, 0]'),
#  Text(0.37330623306233063, 0.4166666666666667, 'x[2] <= 0.46\ngini = 0.403\nsamples = 12\nvalue = [0, 1, 2, 9, 0, 0]'),
#  Text(0.3678861788617886, 0.38333333333333336, 'x[2] <= 0.37\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 8, 0, 0]'),
#  Text(0.36517615176151763, 0.35, 'x[1] <= 0.455\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.3624661246612466, 0.31666666666666665, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3678861788617886, 0.31666666666666665, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3705962059620596, 0.35, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.3787262872628726, 0.38333333333333336, 'x[3] <= 2.2\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 1, 0, 0]'),
#  Text(0.37601626016260165, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3814363143631436, 0.35, 'x[0] <= 7.85\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.3787262872628726, 0.31666666666666665, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.38414634146341464, 0.31666666666666665, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3787262872628726, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3814363143631436, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.4065040650406504, 0.48333333333333334, 'x[3] <= 2.15\ngini = 0.577\nsamples = 43\nvalue = [0, 0, 22, 17, 3, 1]'),
#  Text(0.3976964769647697, 0.45, 'x[0] <= 9.75\ngini = 0.526\nsamples = 17\nvalue = [0, 0, 6, 10, 0, 1]'),
#  Text(0.39498644986449866, 0.4166666666666667, 'x[0] <= 8.7\ngini = 0.48\nsamples = 15\nvalue = [0, 0, 4, 10, 0, 1]'),
#  Text(0.3895663956639566, 0.38333333333333336, 'x[2] <= 0.385\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1]'),
#  Text(0.38685636856368566, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.39227642276422764, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.40040650406504064, 0.38333333333333336, 'x[2] <= 0.435\ngini = 0.355\nsamples = 13\nvalue = [0, 0, 3, 10, 0, 0]'),
#  Text(0.3976964769647697, 0.35, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.40311653116531165, 0.35, 'x[2] <= 0.445\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.40040650406504064, 0.31666666666666665, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.40582655826558267, 0.31666666666666665, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.40040650406504064, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.4153116531165312, 0.45, 'x[1] <= 0.39\ngini = 0.536\nsamples = 26\nvalue = [0, 0, 16, 7, 3, 0]'),
#  Text(0.40853658536585363, 0.4166666666666667, 'x[0] <= 8.75\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.40582655826558267, 0.38333333333333336, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.41124661246612465, 0.38333333333333336, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.42208672086720866, 0.4166666666666667, 'x[2] <= 0.345\ngini = 0.48\nsamples = 23\nvalue = [0, 0, 15, 7, 1, 0]'),
#  Text(0.4166666666666667, 0.38333333333333336, 'x[0] <= 9.4\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.41395663956639567, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.41937669376693765, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.4275067750677507, 0.38333333333333336, 'x[2] <= 0.41\ngini = 0.408\nsamples = 21\nvalue = [0, 0, 15, 6, 0, 0]'),
#  Text(0.4247967479674797, 0.35, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.43021680216802166, 0.35, 'x[2] <= 0.44\ngini = 0.48\nsamples = 15\nvalue = [0, 0, 9, 6, 0, 0]'),
#  Text(0.4275067750677507, 0.31666666666666665, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.4329268292682927, 0.31666666666666665, 'x[1] <= 0.52\ngini = 0.426\nsamples = 13\nvalue = [0, 0, 9, 4, 0, 0]'),
#  Text(0.43021680216802166, 0.2833333333333333, 'x[0] <= 9.6\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 5, 4, 0, 0]'),
#  Text(0.4275067750677507, 0.25, 'x[2] <= 0.46\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.4247967479674797, 0.21666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.43021680216802166, 0.21666666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.4329268292682927, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.4356368563685637, 0.2833333333333333, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.4007452574525745, 0.55, 'x[1] <= 0.425\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 0, 2, 0]'),
#  Text(0.39803523035230354, 0.5166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.4034552845528455, 0.5166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.40887533875338755, 0.5833333333333334, 'x[3] <= 2.35\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1, 0]'),
#  Text(0.40616531165311653, 0.55, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.4115853658536585, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.40752032520325204, 0.6166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.4400406504065041, 0.65, 'x[0] <= 10.25\ngini = 0.642\nsamples = 70\nvalue = [1, 1, 20, 34, 14, 0]'),
#  Text(0.4261517615176152, 0.6166666666666667, 'x[3] <= 2.3\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 0, 4, 0]'),
#  Text(0.4234417344173442, 0.5833333333333334, 'x[3] <= 2.1\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.42073170731707316, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
# ...
#  Text(0.8008130081300813, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8062330623306233, 0.2833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7798102981029811, 0.45, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.787940379403794, 0.48333333333333334, 'x[3] <= 3.95\ngini = 0.278\nsamples = 12\nvalue = [0, 0, 10, 2, 0, 0]'),
#  Text(0.785230352303523, 0.45, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.790650406504065, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.787940379403794, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.787940379403794, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.790650406504065, 0.6166666666666667, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.7987804878048781, 0.65, 'x[2] <= 0.115\ngini = 0.463\nsamples = 11\nvalue = [0, 0, 4, 7, 0, 0]'),
#  Text(0.7960704607046071, 0.6166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.801490514905149, 0.6166666666666667, 'x[3] <= 2.0\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]'),
#  Text(0.7987804878048781, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.80420054200542, 0.5833333333333334, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.8204183604336044, 0.6833333333333333, 'x[3] <= 1.55\ngini = 0.295\nsamples = 86\nvalue = [0, 2, 71, 13, 0, 0]'),
#  Text(0.809620596205962, 0.65, 'x[1] <= 0.597\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]'),
#  Text(0.806910569105691, 0.6166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8123306233062331, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8312161246612466, 0.65, 'x[2] <= 0.215\ngini = 0.251\nsamples = 83\nvalue = [0, 1, 71, 11, 0, 0]'),
#  Text(0.8177506775067751, 0.6166666666666667, 'x[0] <= 6.75\ngini = 0.087\nsamples = 22\nvalue = [0, 0, 21, 1, 0, 0]'),
#  Text(0.8150406504065041, 0.5833333333333334, 'x[1] <= 0.625\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.8123306233062331, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8177506775067751, 0.55, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.8204607046070461, 0.5833333333333334, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 17, 0, 0, 0]'),
#  Text(0.8446815718157181, 0.6166666666666667, 'x[0] <= 8.75\ngini = 0.301\nsamples = 61\nvalue = [0, 1, 50, 10, 0, 0]'),
#  Text(0.8329945799457995, 0.5833333333333334, 'x[0] <= 8.45\ngini = 0.361\nsamples = 44\nvalue = [0, 1, 34, 9, 0, 0]'),
#  Text(0.823170731707317, 0.55, 'x[0] <= 8.05\ngini = 0.302\nsamples = 39\nvalue = [0, 1, 32, 6, 0, 0]'),
#  Text(0.8116531165311653, 0.5166666666666667, 'x[1] <= 0.585\ngini = 0.355\nsamples = 26\nvalue = [0, 0, 20, 6, 0, 0]'),
#  Text(0.7994579945799458, 0.48333333333333334, 'x[3] <= 1.9\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.7967479674796748, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8021680216802168, 0.45, 'x[0] <= 7.45\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.7994579945799458, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8048780487804879, 0.4166666666666667, 'x[0] <= 7.95\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.8021680216802168, 0.38333333333333336, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8075880758807588, 0.38333333333333336, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8238482384823849, 0.48333333333333334, 'x[1] <= 0.71\ngini = 0.255\nsamples = 20\nvalue = [0, 0, 17, 3, 0, 0]'),
#  Text(0.8184281842818428, 0.45, 'x[0] <= 7.45\ngini = 0.117\nsamples = 16\nvalue = [0, 0, 15, 1, 0, 0]'),
#  Text(0.8157181571815718, 0.4166666666666667, 'x[0] <= 7.35\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.8130081300813008, 0.38333333333333336, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.8184281842818428, 0.38333333333333336, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8211382113821138, 0.4166666666666667, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.8292682926829268, 0.45, 'x[1] <= 0.728\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.8265582655826558, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8319783197831978, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8346883468834688, 0.5166666666666667, 'x[2] <= 0.255\ngini = 0.142\nsamples = 13\nvalue = [0, 1, 12, 0, 0, 0]'),
#  Text(0.8319783197831978, 0.48333333333333334, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.8373983739837398, 0.48333333333333334, 'x[1] <= 0.623\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.8346883468834688, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8401084010840109, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8428184281842819, 0.55, 'x[1] <= 0.713\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 2, 3, 0, 0]'),
#  Text(0.8401084010840109, 0.5166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8455284552845529, 0.5166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8563685636856369, 0.5833333333333334, 'x[2] <= 0.225\ngini = 0.111\nsamples = 17\nvalue = [0, 0, 16, 1, 0, 0]'),
#  Text(0.8536585365853658, 0.55, 'x[3] <= 2.05\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.8509485094850948, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8563685636856369, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8590785907859079, 0.55, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0, 0, 0]'),
#  Text(0.8766937669376694, 0.7166666666666667, 'x[1] <= 0.615\ngini = 0.526\nsamples = 35\nvalue = [0, 1, 16, 18, 0, 0]'),
#  Text(0.8672086720867209, 0.6833333333333333, 'x[3] <= 2.75\ngini = 0.508\nsamples = 16\nvalue = [0, 1, 10, 5, 0, 0]'),
#  Text(0.8617886178861789, 0.65, 'x[2] <= 0.295\ngini = 0.278\nsamples = 12\nvalue = [0, 0, 10, 2, 0, 0]'),
#  Text(0.8590785907859079, 0.6166666666666667, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.8644986449864499, 0.6166666666666667, 'x[3] <= 2.25\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.8617886178861789, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8672086720867209, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8726287262872628, 0.65, 'x[1] <= 0.595\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 0, 3, 0, 0]'),
#  Text(0.8699186991869918, 0.6166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8753387533875339, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8861788617886179, 0.6833333333333333, 'x[3] <= 4.25\ngini = 0.432\nsamples = 19\nvalue = [0, 0, 6, 13, 0, 0]'),
#  Text(0.8834688346883469, 0.65, 'x[0] <= 9.5\ngini = 0.305\nsamples = 16\nvalue = [0, 0, 3, 13, 0, 0]'),
#  Text(0.8807588075880759, 0.6166666666666667, 'x[3] <= 3.4\ngini = 0.133\nsamples = 14\nvalue = [0, 0, 1, 13, 0, 0]'),
#  Text(0.8780487804878049, 0.5833333333333334, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.8834688346883469, 0.5833333333333334, 'x[3] <= 4.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.8807588075880759, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8861788617886179, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8861788617886179, 0.6166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8888888888888888, 0.65, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.9051490514905149, 0.75, 'x[0] <= 9.75\ngini = 0.304\nsamples = 29\nvalue = [0, 2, 24, 2, 1, 0]'),
#  Text(0.9024390243902439, 0.7166666666666667, 'x[0] <= 7.45\ngini = 0.255\nsamples = 28\nvalue = [0, 2, 24, 2, 0, 0]'),
#  Text(0.8970189701897019, 0.6833333333333333, 'x[1] <= 0.632\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.8943089430894309, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8997289972899729, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.907859078590786, 0.6833333333333333, 'x[3] <= 2.05\ngini = 0.21\nsamples = 26\nvalue = [0, 1, 23, 2, 0, 0]'),
#  Text(0.9051490514905149, 0.65, 'x[0] <= 8.8\ngini = 0.379\nsamples = 13\nvalue = [0, 1, 10, 2, 0, 0]'),
#  Text(0.8997289972899729, 0.6166666666666667, 'x[2] <= 0.39\ngini = 0.18\nsamples = 10\nvalue = [0, 1, 9, 0, 0, 0]'),
#  Text(0.8970189701897019, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9024390243902439, 0.5833333333333334, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.9105691056910569, 0.6166666666666667, 'x[2] <= 0.495\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.907859078590786, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9132791327913279, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9105691056910569, 0.65, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(0.907859078590786, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9186991869918699, 0.7833333333333333, 'x[1] <= 0.835\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 0, 3, 0, 0]'),
#  Text(0.9159891598915989, 0.75, 'x[0] <= 8.05\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.9132791327913279, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9186991869918699, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9214092140921409, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9349593495934959, 0.8166666666666667, 'x[2] <= 0.13\ngini = 0.244\nsamples = 22\nvalue = [0, 2, 19, 0, 1, 0]'),
#  Text(0.9295392953929539, 0.7833333333333333, 'x[3] <= 2.15\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 3, 0, 1, 0]'),
#  Text(0.926829268292683, 0.75, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.9322493224932249, 0.75, 'x[2] <= 0.11\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]'),
#  Text(0.9295392953929539, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9349593495934959, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.940379403794038, 0.7833333333333333, 'x[2] <= 0.265\ngini = 0.111\nsamples = 17\nvalue = [0, 1, 16, 0, 0, 0]'),
#  Text(0.9376693766937669, 0.75, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.943089430894309, 0.75, 'x[2] <= 0.275\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5, 0, 0, 0]'),
#  Text(0.940379403794038, 0.7166666666666667, 'x[0] <= 8.85\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.9376693766937669, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.943089430894309, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.94579945799458, 0.7166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.975609756097561, 0.8833333333333333, 'x[2] <= 0.655\ngini = 0.669\nsamples = 42\nvalue = [1, 3, 14, 19, 4, 1]'),
#  Text(0.964769647696477, 0.85, 'x[1] <= 0.595\ngini = 0.612\nsamples = 37\nvalue = [1, 3, 14, 18, 1, 0]'),
#  Text(0.9566395663956639, 0.8166666666666667, 'x[2] <= 0.225\ngini = 0.418\nsamples = 15\nvalue = [0, 1, 3, 11, 0, 0]'),
#  Text(0.9539295392953929, 0.7833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.959349593495935, 0.7833333333333333, 'x[2] <= 0.6\ngini = 0.357\nsamples = 14\nvalue = [0, 1, 2, 11, 0, 0]'),
#  Text(0.9566395663956639, 0.75, 'x[3] <= 2.15\ngini = 0.272\nsamples = 13\nvalue = [0, 1, 1, 11, 0, 0]'),
#  Text(0.9512195121951219, 0.7166666666666667, 'x[3] <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.948509485094851, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9539295392953929, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.962059620596206, 0.7166666666666667, 'x[0] <= 12.2\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10, 0, 0]'),
#  Text(0.959349593495935, 0.6833333333333333, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.964769647696477, 0.6833333333333333, 'x[0] <= 12.6\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.962059620596206, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.967479674796748, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.962059620596206, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9728997289972899, 0.8166666666666667, 'x[0] <= 10.05\ngini = 0.636\nsamples = 22\nvalue = [1, 2, 11, 7, 1, 0]'),
#  Text(0.9701897018970189, 0.7833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.975609756097561, 0.7833333333333333, 'x[2] <= 0.27\ngini = 0.66\nsamples = 20\nvalue = [1, 2, 9, 7, 1, 0]'),
#  Text(0.9701897018970189, 0.75, 'x[3] <= 3.05\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]'),
#  Text(0.967479674796748, 0.7166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9728997289972899, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.981029810298103, 0.75, 'x[3] <= 1.6\ngini = 0.623\nsamples = 17\nvalue = [1, 1, 9, 5, 1, 0]'),
#  Text(0.978319783197832, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.983739837398374, 0.7166666666666667, 'x[3] <= 1.85\ngini = 0.578\nsamples = 16\nvalue = [1, 0, 9, 5, 1, 0]'),
#  Text(0.981029810298103, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.986449864498645, 0.6833333333333333, 'x[2] <= 0.41\ngini = 0.56\nsamples = 15\nvalue = [1, 0, 9, 4, 1, 0]'),
#  Text(0.983739837398374, 0.65, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.989159891598916, 0.65, 'x[0] <= 12.6\ngini = 0.645\nsamples = 11\nvalue = [1, 0, 5, 4, 1, 0]'),
#  Text(0.983739837398374, 0.6166666666666667, 'x[2] <= 0.51\ngini = 0.667\nsamples = 6\nvalue = [1, 0, 1, 3, 1, 0]'),
#  Text(0.981029810298103, 0.5833333333333334, 'x[3] <= 2.4\ngini = 0.56\nsamples = 5\nvalue = [1, 0, 1, 3, 0, 0]'),
#  Text(0.978319783197832, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.983739837398374, 0.55, 'x[1] <= 1.022\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.981029810298103, 0.5166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.986449864498645, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.986449864498645, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.994579945799458, 0.6166666666666667, 'x[1] <= 0.742\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.991869918699187, 0.5833333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.997289972899729, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.986449864498645, 0.85, 'x[0] <= 12.1\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 0, 1, 3, 1]'),
#  Text(0.983739837398374, 0.8166666666666667, 'x[0] <= 11.35\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.981029810298103, 0.7833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.986449864498645, 0.7833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.989159891598916, 0.8166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]')]

# %%
predicciones = arbol.predict(X_test)

# %%
predicciones
# Out:
# array([6, 5, 5, 5, 6, 5, 5, 6, 6, 6, 6, 6, 5, 6, 7, 7, 6, 6, 6, 7, 5, 5,
#        7, 5, 5, 6, 6, 6, 6, 6, 7, 6, 5, 6, 6, 6, 5, 5, 5, 6, 7, 7, 6, 6,
#        5, 7, 6, 7, 6, 6, 7, 6, 5, 5, 7, 4, 5, 7, 7, 5, 5, 5, 5, 7, 7, 7,
#        6, 6, 5, 6, 6, 6, 6, 6, 4, 6, 6, 5, 5, 4, 7, 5, 5, 5, 6, 6, 6, 6,
#        6, 5, 4, 6, 4, 5, 5, 6, 6, 5, 6, 6, 6, 7, 5, 5, 5, 6, 5, 5, 5, 7,
#        7, 6, 7, 5, 6, 7, 7, 7, 5, 6, 5, 5, 6, 6, 6, 6, 5, 5, 6, 7, 6, 5,
#        6, 7, 6, 5, 7, 5, 6, 6, 5, 5, 3, 6, 5, 5, 6, 5, 7, 6, 5, 6, 7, 5,
#        5, 5, 6, 6, 6, 5, 5, 6, 6, 6, 7, 6, 5, 6, 6, 5, 5, 5, 5, 4, 6, 5,
#        5, 7, 5, 5, 6, 6, 6, 5, 6, 5, 6, 6, 5, 5, 5, 6, 6, 5, 6, 5, 7, 7,
#        5, 4, 6, 6, 6, 6, 4, 6, 6, 5, 5, 5, 5, 5, 4, 6, 6, 5, 6, 6, 6, 6,
#        6, 5, 5, 5, 6, 6, 5, 6, 5, 6, 6, 6, 6, 5, 6, 6, 6, 5, 6, 5, 6, 6,
#        5, 7, 5, 6, 7, 5, 5, 5, 6, 5, 5, 6, 6, 6, 7, 6, 5, 5, 6, 6, 7, 5,
#        5, 6, 6, 7, 5, 6, 6, 5, 5, 5, 4, 4, 6, 5, 5, 5, 5, 7, 6, 5, 7, 5,
#        5, 7, 5, 5, 6, 6, 6, 6, 5, 7, 6, 5, 5, 5, 5, 6, 6, 6, 5, 7, 6, 6,
#        6, 4, 6, 5, 5, 5, 5, 6, 5, 5, 5, 5], dtype=int64)

# %%
# Examinamos la matriz de confusión
pd.crosstab(np.array([y[0] for y in y_test.values.tolist()]), predicciones, rownames=['Actual'], colnames=['Predicciones'])
# Out:
# Predicciones  3  4   5   6   7
# Actual
# 3             0  0   0   1   0
# 4             0  0   6   2   0
# 5             1  7  89  40   9
# 6             0  5  25  79  15
# 7             0  0   5  13  17
# 8             0  0   2   2   2

# %%
accuracy = accuracy_score(y_test,predicciones)
accuracy
# Out:
# 0.578125

# %%
precision = precision_score(y_test, predicciones, average='weighted')
precision
# Out:
# C:\Users\jvargali\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 0.5864244361477604

# %%
recall = recall_score(y_test, predicciones, average='weighted')
recall
# Out:
# 0.578125

# %%
f1 = f1_score(y_test, predicciones, average='weighted')
f1
# Out:
# 0.5797365110942697
